# %%
# %matplotlib inline
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

from keras.layers import TimeDistributed, Activation, Embedding, SimpleRNN, LSTM, Dropout, Dense
from keras.models import Sequential
from keras.optimizers import Adam
from keras.models import load_model

import numpy as np
from numpy.random import choice
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Prepare dataset

# %%
'''Open text file for our training data'''
text = open('shakespeare.txt').read().lower()

# %%
chars = sorted(list(set(text)))
chars.insert(0, "\0") #Add newline character
vocab_size = len(chars)
''.join(chars[1:])
# Out:
# "\n !',-.:;?abcdefghijklmnopqrstuvwxyz"

# %%
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
idx = [char_indices[c] for c in text]
''.join(indices_char[i] for i in idx[:70])
# Out:
# 'scene v. florence. without the walls. a tucket afar off.\n\nenter an old'

# %%
'''Form the dataset in sentences'''
sentences_length = 100
sentences = []
next_chars = []
for i in range(0, len(idx) - sentences_length + 1):
    sentences.append(idx[i: i + sentences_length]) #Assume a sentence is made of 100 characters
    next_chars.append(idx[i + 1: i + sentences_length + 1]) #Offset by 1 to the right for the target

# %%
sentences = np.concatenate([[np.array(o)] for o in sentences[:-2]])
next_chars = np.concatenate([[np.array(o)] for o in next_chars[:-2]])
sentences.shape, next_chars.shape
# Out:
# ((57934, 100), (57934, 100))

# %% [markdown]
# ## Create the model or load trained model

# %%
'''Load model - do not run the next 3 cells if this cell is used'''
#model = load_model('rnn.h5')
#model.compile(Adam(), loss = 'sparse_categorical_crossentropy')
# Out:
# 'Load model - do not run the next 3 cells if this cell is used'

# %%
embedding_size = 50
model = Sequential([
        Embedding(vocab_size, embedding_size, input_length = sentences_length),
        SimpleRNN(512, 
             return_sequences = True, #Return outputs at every time step
             input_shape = (None, embedding_size),
            ),
        TimeDistributed(Dense(vocab_size)),
        Activation('softmax')
    ])

# %%
model.compile(Adam(), loss = 'sparse_categorical_crossentropy')

# %% [markdown]
# ## Train

# %%
model.fit(sentences, np.expand_dims(next_chars,-1), batch_size = 256, epochs = 250)
# Out:
# Epoch 1/250
# 57934/57934 [==============================] - 8s 142us/step - loss: 2.4223
# Epoch 2/250
# 57934/57934 [==============================] - 8s 135us/step - loss: 1.6870 1s
# Epoch 3/250
# 57934/57934 [==============================] - 8s 133us/step - loss: 1.1412
# Epoch 4/250
# 57934/57934 [==============================] - 8s 133us/step - loss: 0.8370
# Epoch 5/250
# 57934/57934 [==============================] - 8s 132us/step - loss: 0.6659
# Epoch 6/250
# 57934/57934 [==============================] - 8s 134us/step - loss: 0.5636
# Epoch 7/250
# 57934/57934 [==============================] - 8s 136us/step - loss: 0.4991
# Epoch 8/250
# 57934/57934 [==============================] - 8s 135us/step - loss: 0.4548
# Epoch 9/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.4219
# Epoch 10/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.3954
# Epoch 11/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.3733
# Epoch 12/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.3544
# Epoch 13/250
# 57934/57934 [==============================] - 7s 128us/step - loss: 0.3372
# Epoch 14/250
# 57934/57934 [==============================] - 7s 129us/step - loss: 0.3236
# Epoch 15/250
# 57934/57934 [==============================] - 7s 128us/step - loss: 0.3111
# Epoch 16/250
# 57934/57934 [==============================] - 7s 129us/step - loss: 0.2997
# Epoch 17/250
# 57934/57934 [==============================] - 7s 128us/step - loss: 0.2892
# Epoch 18/250
# 57934/57934 [==============================] - 7s 128us/step - loss: 0.2799
# Epoch 19/250
# 57934/57934 [==============================] - 7s 129us/step - loss: 0.2710
# Epoch 20/250
# 57934/57934 [==============================] - 7s 128us/step - loss: 0.2637
# Epoch 21/250
# 57934/57934 [==============================] - 7s 129us/step - loss: 0.2561
# Epoch 22/250
# 57934/57934 [==============================] - 7s 129us/step - loss: 0.2493 0s - loss: 0.24
# Epoch 23/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.2432
# Epoch 24/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.2373
# Epoch 25/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.2319
# Epoch 26/250
# 57934/57934 [==============================] - 7s 129us/step - loss: 0.2271
# Epoch 27/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.2225
# Epoch 28/250
# 57934/57934 [==============================] - 7s 129us/step - loss: 0.
250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1160
# Epoch 159/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1158
# Epoch 160/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1155
# Epoch 161/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1155
# Epoch 162/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1152
# Epoch 163/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1153
# Epoch 164/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1151 1s - loss: 0. - ET
# Epoch 165/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1150
# Epoch 166/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1150
# Epoch 167/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1150
# Epoch 168/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1149
# Epoch 169/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1146
# Epoch 170/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1146
# Epoch 171/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1143
# Epoch 172/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1144
# Epoch 173/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1143
# Epoch 174/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1141
# Epoch 175/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1141
# Epoch 176/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1140
# Epoch 177/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1140
# Epoch 178/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1138 1
# Epoch 179/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1138
# Epoch 180/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1138
# Epoch 181/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1134
# Epoch 182/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1134
# Epoch 183/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1134
# Epoch 184/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1133
# Epoch 185/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1132
# Epoch 186/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1130
# Epoch 187/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1131
# Epoch 188/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1131
# Epoch 189/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1131
# Epoch 190/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1128
# Epoch 191/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1129
# Epoch 192/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1127
# Epoch 193/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1124
# Epoch 194/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1127
# Epoch 195/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1126
# Epoch 196/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1124
# Epoch 197/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1125
# Epoch 198/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1122
# Epoch 199/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1123
# Epoch 200/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1122
# Epoch 201/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1121
# Epoch 202/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1120
# Epoch 203/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1120
# Epoch 204/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1117
# Epoch 205/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1119
# Epoch 206/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1119
# Epoch 207/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1116
# Epoch 208/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1117
# Epoch 209/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1115
# Epoch 210/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1116
# Epoch 211/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1114
# Epoch 212/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1114
# Epoch 213/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1113
# Epoch 214/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1111
# Epoch 215/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1111
# Epoch 216/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1110
# Epoch 217/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1111
# Epoch 218/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1111
# Epoch 219/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1109
# Epoch 220/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1108
# Epoch 221/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1108
# Epoch 222/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1107
# Epoch 223/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1108
# Epoch 224/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1108
# Epoch 225/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1108
# Epoch 226/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1107
# Epoch 227/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1105 0s
# Epoch 228/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1104
# Epoch 229/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1104
# Epoch 230/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1104
# Epoch 231/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1104
# Epoch 232/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1103
# Epoch 233/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1103
# Epoch 234/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1101
# Epoch 235/250
# 57934/57934 [==============================] - 8s 131us/step - loss: 0.1100
# Epoch 236/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1100
# Epoch 237/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1102
# Epoch 238/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1101
# Epoch 239/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1099
# Epoch 240/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1101
# Epoch 241/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1097
# Epoch 242/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1099
# Epoch 243/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1099
# Epoch 244/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1099
# Epoch 245/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1096
# Epoch 246/250
# 57934/57934 [==============================] - 8s 130us/step - loss: 0.1097
# Epoch 247/250
# 57934/57934 [==============================] - 8s 133us/step - loss: 0.1096
# Epoch 248/250
# 57934/57934 [==============================] - 8s 137us/step - loss: 0.1098
# Epoch 249/250
# 57934/57934 [==============================] - 8s 137us/step - loss: 0.1093
# Epoch 250/250
# 57934/57934 [==============================] - 8s 136us/step - loss: 0.1094

# %% [markdown]
# ## Predict next characters

# %%
def predict_next_chars(init_chars, chars_to_predict = 50):
    l = len(init_chars)
    for i in range(chars_to_predict):
        x = np.array([char_indices[c] for c in init_chars[-l:]])[np.newaxis,:]
        pred = model.predict(x)[0][-1]
        pred = pred / np.sum(pred)
        predicted_character = choice(chars, p = pred)
        init_chars += predicted_character
    print(init_chars)

# %%
'''Lets give an input to LSTM (100 chars) and see its predictions for every time step'''
init_chars = "my name is reyrez and i have been solicited by neural networks that tries to generate new characters"
predict_next_chars(init_chars, chars_to_predict = 200)
# Out:
# my name is reyrez and i have been solicited by neural networks that tries to generate new characters i dearly groan,
# whereat each tributary subject quakes;
# as when the wird is her face illumined with her eye;
# whose beams upon his hairless face are fix'd,
# as if from thence they borrow'd all their shi

# %%
model.save('rnn.h5')
